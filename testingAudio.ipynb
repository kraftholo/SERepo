# %%
import torchaudio
import torch
import sounddevice as sd
import IPython.display as ipd
import numpy as np

# %%
print(f'torchaudio backend : {torchaudio.get_audio_backend()}')
waveform_train, sample_rate = torchaudio.load('archive/train/19-198-0003.wav')
waveform_test, sample_rate = torchaudio.load('archive/y_train/19-198-0003.wav')
# Out:
# torchaudio backend : soundfile

# %%
# Train Audio
print(f'First 20 samples: {waveform_train[0, :20]}')
print(f'waveform_train shape = {waveform_train.shape}')
print(f'Sample rate = {sample_rate}')
ipd.Audio(waveform_train, rate=sample_rate)
# Out:
# First 20 samples: tensor([ 0.0128, -0.0086, -0.0266, -0.0442, -0.0578, -0.0630, -0.0646, -0.0570,
#         -0.0393, -0.0298, -0.0309, -0.0293, -0.0269, -0.0239, -0.0124, -0.0039,
#         -0.0031,  0.0087,  0.0289,  0.0359])
# waveform_train shape = torch.Size([1, 247680])
# Sample rate = 16000
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(f'First 20 samples: {waveform_test[0, :20]}')
print(f'waveform_test shape = {waveform_test.shape}')
print(f'Sample rate = {sample_rate}')
ipd.Audio(waveform_test, rate=sample_rate)
# Out:
# First 20 samples: tensor([-0.0020, -0.0014, -0.0017, -0.0015, -0.0019, -0.0015, -0.0014, -0.0014,
#         -0.0014, -0.0015, -0.0019, -0.0027, -0.0031, -0.0030, -0.0027, -0.0038,
#         -0.0051, -0.0046, -0.0042, -0.0037])
# waveform_test shape = torch.Size([1, 247680])
# Sample rate = 16000
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
